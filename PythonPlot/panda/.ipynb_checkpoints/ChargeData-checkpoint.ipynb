# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from pandas import ExcelWriter
from pandas import ExcelFile
from datetime import datetime

Table = pd.read_csv("INFORMACION_SOCIODEMOGRAFICA.csv")
T8 = pd.read_csv(pathwork+namedata[7]+'.csv')
n8,m8=T8.shape

"""
#Crear tablas para procesos
#T1_sort=T1.sort_values("process_id")
#Hacemos una serie con los valores que no son terminados en la misma sucursal
slayproc=T1[T1["initial_branch_id"]!=T1["last_branch_id"]]["process_id"]
sn,=slayproc.shape
T1_clean=T1.copy()
#Luego los borramos
for i in range(0,sn):
    T1_clean=T1_clean.drop(slayproc.index[i])
#Limpiamos T2 de esos procesos
T2_clean=T2.copy()
slayproc2=np.array([])
#Ubicamos esos procesos en la tabla 2
for i in range(0,sn):
    slayproc2=np.append(slayproc2,(T2_clean[T1["process_id"][slayproc.index[i]]==T2_clean["process_id"]].index))
#Luego los borramos
sn2=len(slayproc2)
for i in range(0,sn2):
    T2_clean=T2_clean.drop(slayproc2[i])
    
#Limpiamos T3 de esos procesos
T3_clean=T3.copy()
slayproc3=np.array([])
#Ubicamos esos procesos en la tabla 3
for i in range(0,sn):
    slayproc3=np.append(slayproc3,(T3_clean[T1["process_id"][slayproc.index[i]]==T3_clean["process_id"]].index))
#Luego los borramos
sn3=len(slayproc3)
for i in range(0,sn):
    T3_clean=T3_clean.drop(slayproc3[i])
#Ahora creamos las tablas por sucursales
T1_sub=list()
for i in range(0,n8):
    T1_sub.append(T1_clean[T1_clean["initial_branch_id"]==T8["qf_branch_id"][i]])

#T2_sub=list()
#for i in range(0,n8):
#    T2_sub.append(T2_clean[T2_clean["qf_branch_id"]==T8["qf_branch_id"][i]])

#T3_sub=list()
#for i in range(0,n8):
#    T3_sub.append(T3_clean[T3_clean["initial_branch_id"]==T8["qf_branch_id"][i]])
#Tiempo para 1

for i in range(0,n8):
    time_up       = T1_sub[i]["arrival_dt"].values
    time_up_split = np.array([tt.split(" ") for tt in time_up])
    time          = np.array([tt.split(":") for tt in time_up_split[:,1]],dtype="float64")
    date          = np.array([tt.split("-") for tt in time_up_split[:,0]])
    T1_sub[i].insert(loc=1, column='arrival_month', value=date[:,1])
    #T1_sub[i].insert(loc=2, column='d_arrival', value=date[:,2])
    #T1_sub[i].insert(loc=3, column='hour_arrival', value=time[:,0])
    #T1_sub[i].insert(loc=4, column='min_arrival',  value=time[:,1])
    #T1_sub[i].insert(loc=5, column='seg_arrival',  value=time[:,2])

#for i in range(0,n8):
#    time_up       = T1_sub[i]["last_update_dt"].values
#    time_up_split = np.array([tt.split(" ") for tt in time_up])
#    time          = np.array([tt.split(":") for tt in time_up_split[:,1]],dtype="float64")
#    date          = np.array([tt.split("-") for tt in time_up_split[:,0]])
#    T1_sub[i].insert(loc=12, column='m_last', value=date[:,1])
#    T1_sub[i].insert(loc=13, column='d_last', value=date[:,2])
#    T1_sub[i].insert(loc=14, column='hour_last', value=time[:,0])
#    T1_sub[i].insert(loc=15, column='min_last',  value=time[:,1])
#    T1_sub[i].insert(loc=16, column='seg_last',  value=time[:,2])

for i in range(0,n8):
    namesave="T1_branch_"+str(T8["qf_branch_id"][i])
    T1_sub[i].sort_values("process_id").to_csv(pathwork+'datos_branch/'+namesave+'.csv', sep=',', index=False)
    #namesave="T2_branch_"+str(T8["qf_branch_id"][i])
    #T2_sub[i].sort_values("process_id").to_csv(pathwork+'datos_branch/'+namesave+'.csv', sep=',', index=False)
    #namesave="T3_branch_"+str(T8["qf_branch_id"][i])
    #T3_sub[i].sort_values("process_id").to_csv(pathwork+'datos_branch/'+namesave+'.csv', sep=',', index=False)
"""

# %%
test  = T1_sub[0]["arrival_dt"].values
test2 = np.array([tt.split(" ") for tt in test])
date1  = test2[:,0]
time1  = test2[:,1]
time_s= np.array([tt.split(":") for tt in time],dtype="float64")
date = np.array([tt.split("-") for tt in date1])
#test2 = np.array(test2,dtype='datetime64[us]').astype('datetime64[D]')
# Out:
# array([['2017', '10', '25'],
#        ['2017', '10', '25'],
#        ['2017', '10', '25'],
#        ...,
#        ['2017', '10', '25'],
#        ['2017', '10', '25'],
#        ['2017', '10', '25']],
#       dtype='|S4')

# %%
import Funaux as F
F.aja()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-19b0abaa2d25> in <module>()
# ----> 1 import Funaux as F
#       2 F.aja()
#
# ImportError: No module named 'Funaux'

# %%
T1_sub[1]
# Out:
#          process_id                  arrival_dt  initialservice_id  \
# 169        96254885  2017-10-25 10:48:21.530000               2316
# 299        96260010  2017-10-25 10:59:10.380000               2316
# 390        96263324  2017-10-25 11:06:19.250000               2319
# 433        96264739  2017-10-25 11:09:29.697000               2316
# 508        96268306  2017-10-25 11:17:30.580000               2316
# 602        96272344  2017-10-25 11:26:21.380000               2314
# 630        96273349  2017-10-25 11:28:39.100000               2316
# 652        96274082  2017-10-25 11:30:27.470000               2316
# 1647       96313932  2017-10-25 13:59:54.673000               2316
# 1707       96316627  2017-10-25 14:05:00.207000               2316
# 1795       96319888  2017-10-25 14:11:55.197000               2316
# 1802       96320109  2017-10-25 14:12:22.283000               2313
# 1804       96320216  2017-10-25 14:12:37.330000               2316
# ...

# %%
time[0]
# Out:
# array([ 10.  ,  39.  ,  22.71])
